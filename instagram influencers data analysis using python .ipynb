# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_insta = pd.read_csv(r"C:\Users\akshu\Desktop\instagram_global_top_1000.csv")
df_insta.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# 2  306300000.0        Argentina             4800000.0       6500000.0
# 3  217800000.0    United States             3400000.0       5400000.0
# 4  295800000.0    United States             2700000.0       3600000.0
#
#                       Scraped
# 0  2022-02-07 16:50:24.798803
# 1  2022-02-07 16:50:24.798803
# 2  2022-02-07 16:50:24.798803
# 3  2022-02-07 16:50:24.798803
# 4  2022-02-07 16:50:24.798803

# %%
df_insta.info
# Out:
# <bound method DataFrame.info of     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# 2         https://www.instagram.com/leomessi/
# 3    https://www.instagram.com/kendalljenner/
# 4      https://www.instagram.com/selenagomez/
# ..                                        ...
# 995  https://www.instagram.com/senoritasaeva/
# 996    https://www.instagram.com/manuelneuer/
# 997      https://www.instagram.com/sahilkhan/
# 998    https://www.instagram.com/mohanshakti/
# 999       https://www.instagram.com/eduincaz/
#
#                                 Category    Followers Audience Country  \
# 0                     Sports with a ball  400100000.0            India
# 1                Fashion|Modeling|Beauty  308800000.0    United States
# 2              Sports with a ball|Family  306300000.0        Argentina
# 3                       Modeling|Fashion  217800000.0    United States
# 4                        Music|Lifestyle  295800000.0    United States
# ..                                   ...          ...              ...
# 995             Lifestyle|Music|Modeling    7700000.0           Russia
# 996                   Sports with a ball   11500000.0          Germany
# 997                          Fitness|Gym   10100000.0            India
# 998  Art|Artists|Cinema|Actors/actresses   13700000.0            India
# 999                            Lifestyle    6200000.0           Mexico
#
#      Authentic engagement  Engagement avg                     Scraped
# 0               7800000.0       9500000.0  2022-02-07 16:50:24.798803
# 1               6200000.0      10100000.0  2022-02-07 16:50:24.798803
# 2               4800000.0       6500000.0  2022-02-07 16:50:24.798803
# 3               3400000.0       5400000.0  2022-02-07 16:50:24.798803
# 4               2700000.0       3600000.0  2022-02-07 16:50:24.798803
# ..                    ...             ...                         ...
# 995              246600.0        318200.0  2022-02-07 16:50:24.798803
# 996              146500.0        210200.0  2022-02-07 16:50:24.798803
# 997              176500.0        239800.0  2022-02-07 16:50:24.798803
# 998              146400.0        175500.0  2022-02-07 16:50:24.798803
# 999              305600.0        391900.0  2022-02-07 16:50:24.798803
#
# [1000 rows x 11 columns]>

# %%
df_insta.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
#returning relative frequency of audience country elements

# %%
#almost 28% of 1000 influencers are from USA as their audience country

# %%
df_insta["Audience Country"].value_counts(normalize=True).round(2)
# Out:
# United States           0.28
# Brazil                  0.16
# India                   0.14
# Indonesia               0.13
# Mexico                  0.05
# Spain                   0.03
# Russia                  0.03
# Argentina               0.02
# United Kingdom          0.02
# Iran                    0.02
# Turkey                  0.02
# Italy                   0.02
# South Korea             0.01
# Colombia                0.01
# Philippines             0.01
# France                  0.01
# Egypt                   0.01
# Germany                 0.01
# Nigeria                 0.00
# Iraq                    0.00
# Thailand                0.00
# Morocco                 0.00
# Japan                   0.00
# Saudi Arabia            0.00
# Kazakhstan              0.00
# Poland                  0.00
# Syria                   0.00
# United Arab Emirates    0.00
# China                   0.00
# Algeria                 0.00
# Chile                   0.00
# Name: Audience Country, dtype: float64

# %%
#creating pivot table to show statistics for different categories
df_insta.pivot_table(index="Category", values="Followers", aggfunc=['mean', 'sum', 'min', 'max'])
# Out:
#                                                         mean          sum  \
#                                                    Followers    Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  4.710000e+07   47100000.0
# Adult content                                   1.098571e+07   76900000.0
# Animals                                         1.000000e+07   10000000.0
# Art|Artists                                     1.743333e+07   52300000.0
# Art|Artists|Beauty                              1.810000e+07   18100000.0
# ...                                                      ...          ...
# Sports with a ball|Family                       1.730500e+08  346100000.0
# Sports with a ball|Lifestyle                    2.082500e+07   83300000.0
# Sports with a ball|Lifestyle|Kids|Toys          1.540000e+07   15400000.0
# Sports with a ball|Literature|Journalism        1.570000e+07   15700000.0
# Sports with a ball|Shows                        2.840000e+07   28400000.0
#
#                                                        min          max
#                                                  Followers    Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  47100000.0   47100000.0
# Adult content                                    4900000.0   16300000.0
# Animals                                         10000000.0   10000000.0
# Art|Artists                                     12400000.0   25000000.0
# Art|Artists|Beauty                              18100000.0   18100000.0
# ...                                                    ...          ...
# Sports with a ball|Family                       39800000.0  306300000.0
# Sports with a ball|Lifestyle                    11200000.0   32900000.0
# Sports with a ball|Lifestyle|Kids|Toys          15400000.0   15400000.0
# Sports with a ball|Literature|Journalism        15700000.0   15700000.0
# Sports with a ball|Shows                        28400000.0   28400000.0
#
# [165 rows x 4 columns]

# %%
df_usa = df_insta[df_insta['Audience Country'] == 'United States']
df_usa.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 1  308800000.0    United States             6200000.0      10100000.0
# 3  217800000.0    United States             3400000.0       5400000.0
# 4  295800000.0    United States             2700000.0       3600000.0
# 5  127800000.0    United States             5800000.0       7800000.0
# 6  284900000.0    United States             2200000.0       3300000.0
#
#                       Scraped
# 1  2022-02-07 16:50:24.798803
# 3  2022-02-07 16:50:24.798803
# 4  2022-02-07 16:50:24.798803
# 5  2022-02-07 16:50:24.798803
# 6  2022-02-07 16:50:24.798803

# %%
#converting floats to ints

df_usa = df_usa.astype({"Followers":"int","Authentic engagement":"int", "Engagement avg":"int"})
df_usa.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#    Followers Audience Country  Authentic engagement  Engagement avg  \
# 1  308800000    United States               6200000        10100000
# 3  217800000    United States               3400000         5400000
# 4  295800000    United States               2700000         3600000
# 5  127800000    United States               5800000         7800000
# 6  284900000    United States               2200000         3300000
#
#                       Scraped
# 1  2022-02-07 16:50:24.798803
# 3  2022-02-07 16:50:24.798803
# 4  2022-02-07 16:50:24.798803
# 5  2022-02-07 16:50:24.798803
# 6  2022-02-07 16:50:24.798803

# %%
#pivot table to show statistics on category followers in usa
df_usa.pivot_table(index="Category", values="Followers", aggfunc = ['mean', 'sum', 'min', 'max'])
# Out:
#                                                         mean        sum  \
#                                                    Followers  Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  4.710000e+07   47100000
# Adult content                                   1.087500e+07   43500000
# Art|Artists                                     1.490000e+07   14900000
# Art|Artists|Beauty                              1.810000e+07   18100000
# Art|Artists|Cinema|Actors/actresses|Shows       2.060000e+07   20600000
# ...                                                      ...        ...
# Sports with a ball                              2.753636e+07  302900000
# Sports with a ball|Family                       3.980000e+07   39800000
# Sports with a ball|Lifestyle                    1.120000e+07   11200000
# Sports with a ball|Lifestyle|Kids|Toys          1.540000e+07   15400000
# Sports with a ball|Shows                        2.840000e+07   28400000
#
#                                                      min        max
#                                                Followers  Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  47100000   47100000
# Adult content                                    4900000   16300000
# Art|Artists                                     14900000   14900000
# Art|Artists|Beauty                              18100000   18100000
# Art|Artists|Cinema|Actors/actresses|Shows       20600000   20600000
# ...                                                  ...        ...
# Sports with a ball                               7100000  111400000
# Sports with a ball|Family                       39800000   39800000
# Sports with a ball|Lifestyle                    11200000   11200000
# Sports with a ball|Lifestyle|Kids|Toys          15400000   15400000
# Sports with a ball|Shows                        28400000   28400000
#
# [92 rows x 4 columns]

# %%
#converting floats to ints
df_usa = df_usa.astype({"Followers":"int","Authentic engagement":"int","Engagement avg":"int"})
df_usa.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#    Followers Audience Country  Authentic engagement  Engagement avg  \
# 1  308800000    United States               6200000        10100000
# 3  217800000    United States               3400000         5400000
# 4  295800000    United States               2700000         3600000
# 5  127800000    United States               5800000         7800000
# 6  284900000    United States               2200000         3300000
#
#                       Scraped
# 1  2022-02-07 16:50:24.798803
# 3  2022-02-07 16:50:24.798803
# 4  2022-02-07 16:50:24.798803
# 5  2022-02-07 16:50:24.798803
# 6  2022-02-07 16:50:24.798803

# %%
# pivot table to show statistics on category followers in the United States

df_usa.pivot_table(index="Category", values="Followers", aggfunc=['mean', 'sum', 'min', 'max'])
# Out:
#                                                         mean        sum  \
#                                                    Followers  Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  4.710000e+07   47100000
# Adult content                                   1.087500e+07   43500000
# Art|Artists                                     1.490000e+07   14900000
# Art|Artists|Beauty                              1.810000e+07   18100000
# Art|Artists|Cinema|Actors/actresses|Shows       2.060000e+07   20600000
# ...                                                      ...        ...
# Sports with a ball                              2.753636e+07  302900000
# Sports with a ball|Family                       3.980000e+07   39800000
# Sports with a ball|Lifestyle                    1.120000e+07   11200000
# Sports with a ball|Lifestyle|Kids|Toys          1.540000e+07   15400000
# Sports with a ball|Shows                        2.840000e+07   28400000
#
#                                                      min        max
#                                                Followers  Followers
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion  47100000   47100000
# Adult content                                    4900000   16300000
# Art|Artists                                     14900000   14900000
# Art|Artists|Beauty                              18100000   18100000
# Art|Artists|Cinema|Actors/actresses|Shows       20600000   20600000
# ...                                                  ...        ...
# Sports with a ball                               7100000  111400000
# Sports with a ball|Family                       39800000   39800000
# Sports with a ball|Lifestyle                    11200000   11200000
# Sports with a ball|Lifestyle|Kids|Toys          15400000   15400000
# Sports with a ball|Shows                        28400000   28400000
#
# [92 rows x 4 columns]

# %%
df_usa.pivot_table(index="Category", values="Engagement avg", aggfunc=['mean', 'sum', 'min', 'max'])
# Out:
#                                                          mean            sum  \
#                                                Engagement avg Engagement avg
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion   54000.000000          54000
# Adult content                                   354900.000000        1419600
# Art|Artists                                     400900.000000         400900
# Art|Artists|Beauty                              798200.000000         798200
# Art|Artists|Cinema|Actors/actresses|Shows       161600.000000         161600
# ...                                                       ...            ...
# Sports with a ball                              437509.090909        4812600
# Sports with a ball|Family                       725500.000000         725500
# Sports with a ball|Lifestyle                    287300.000000         287300
# Sports with a ball|Lifestyle|Kids|Toys          483900.000000         483900
# Sports with a ball|Shows                        174300.000000         174300
#
#                                                           min            max
#                                                Engagement avg Engagement avg
# Category
# Accessories|Jewellery|Clothing|Outfits|Fashion          54000          54000
# Adult content                                          225600         526500
# Art|Artists                                            400900         400900
# Art|Artists|Beauty                                     798200         798200
# Art|Artists|Cinema|Actors/actresses|Shows              161600         161600
# ...                                                       ...            ...
# Sports with a ball                                      98100        1500000
# Sports with a ball|Family                              725500         725500
# Sports with a ball|Lifestyle                           287300         287300
# Sports with a ball|Lifestyle|Kids|Toys                 483900         483900
# Sports with a ball|Shows                               174300         174300
#
# [92 rows x 4 columns]

# %%
#showing categories with most followers 
topfollowers = df_usa.nlargest(10, 'Followers')

topfollowers.pivot_table(index="Category", values="Followers", aggfunc = ['sum'])
# Out:
#                                                     sum
#                                               Followers
# Category
# Clothing|Outfits|Lifestyle                    219400000
# Fashion|Beauty                                284900000
# Fashion|Modeling|Beauty                       308800000
# Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000
# Modeling|Fashion                              217800000
# Music                                         294100000
# Music|Cinema|Actors/actresses                 194900000
# Music|Fashion                                 237200000
# Music|Lifestyle                               295800000
# Nature  landscapes|Science|Photography        206600000

# %%
#creating dataframe for top 20 followers 
top20 = df_usa.nlargest(20,'Followers')

# %%
#showinf categories with most avg audience engagement 
topengavg = df_usa.nlargest(20,'Engagement avg')
topengavg.pivot_table(index="Category", values="Engagement avg")
# Out:
#                                  Engagement avg
# Category
# Cinema|Actors/actresses                 5250000
# Cinema|Actors/actresses|Fashion         7800000
# Fashion|Beauty                          3300000
# Fashion|Modeling|Beauty                10100000
# Lifestyle|Shows                         2400000
# Modeling|Fashion                        5400000
# Music                                   4200000
# Music|Beauty                            2800000
# Music|Fashion                           3100000
# Music|Lifestyle                         3600000

# %%
# showing the categories with the most authentic audience engagement

topengagement = df_usa.nlargest(20,'Authentic engagement')

topengagement.pivot_table(index="Category", values="Authentic engagement")
# Out:
#                                  Authentic engagement
# Category
# Cinema|Actors/actresses                       3950000
# Cinema|Actors/actresses|Fashion               5800000
# Fashion|Beauty                                2200000
# Fashion|Modeling|Beauty                       6200000
# Lifestyle|Shows                               1900000
# Modeling|Fashion                              3400000
# Music                                         3200000
# Music|Beauty                                  1700000
# Music|Fashion                                 2150000
# Music|Lifestyle                               2700000

# %%
# creating a new fashion category dataframe to include all of the subsets

fashion = df_usa[df_usa['Category'].str.contains('Fashion', na=False)]
fashion.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
# 7     All     8        beyonce             Beyoncé
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
# 7        https://www.instagram.com/beyonce/                    Music|Fashion
#
#    Followers Audience Country  Authentic engagement  Engagement avg  \
# 1  308800000    United States               6200000        10100000
# 3  217800000    United States               3400000         5400000
# 5  127800000    United States               5800000         7800000
# 6  284900000    United States               2200000         3300000
# 7  237200000    United States               2500000         3600000
#
#                       Scraped
# 1  2022-02-07 16:50:24.798803
# 3  2022-02-07 16:50:24.798803
# 5  2022-02-07 16:50:24.798803
# 6  2022-02-07 16:50:24.798803
# 7  2022-02-07 16:50:24.798803

# %%
#plotting dor followers
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers.Category, topfollowers.Followers, label = 'Followers', width = 0.8, color = 'red')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 10 Categories by Followers", fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis = "y", style = 'plain')

# %%
# plotting followers

plt.figure(figsize=(12,8))
fig2 = plt.bar(top20.Category, top20.Followers, label='Followers', width=0.8, color='green')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 20 Categories by Followers", fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis="y", style='plain')

# %%
# plotting the number of accounts between 0 and 60 million followers

plt.figure(figsize=(12,8))
plt.hist(df_usa.Followers, color='skyblue', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the US', fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(style='plain')
